# %% [markdown]
# # House Prices: Data Health, Feature Effects, Baseline
#
# Before building and training models, it is often useful to understand:
#
# - how clean is the data
# - are there synthetic features that add value
# - which features matter most
# - what a simple model looks like
# - how the model compares to a naive baseline
#
# These checks help avoid spending time optimizing models on datasets that may have deeper issues.
# The diagnostics shown below were generated automatically using a dataset analysis tool.

# %% [markdown]
# ## Data Health
#
# ![Data Health](house_prices_data_health.png)
#
# The data health reports highlight issues such as:
#
# - missing values
# - low-variance columns
# - potential target imbalance
#
# This can help prioritize which columns may need cleaning, transformation, or removal before training models.

# %% [markdown]
# ## Feature Effects
# <img src="house_prices_features.png" width="600">
#
# - **OverallQual**, **TotalBsmtSF**, and **GrLivArea** dominate feature importance.
# - The synthetic interaction features (**GrLivArea** × **GrLivArea**) and (**LotArea** × **GrLivArea**) contribute some signal, but less strongly.

# %% [markdown]
# ## Model Overview
#
# <img src="house_prices_model.png" width="600">
#
# - The model's training RMSLE is 0.1300, and the model's validation RMSLE is 0.1473.
# - The small gap between training and validation RMSLE suggests limited overfitting.

# %% [markdown]
# ## Baseline
#
# <img src="house_prices_baseline.png" width="600">
#
# - A naive baseline that predicts the mean sale price results in an RMSLE of 0.3993.
# - The model has a relative improvement of 63.1% over this naive baseline.

# %% [markdown]
# ## Notes
#
# The analysis above was generated automatically using **predictly.cloud** (free site).  It can be useful for quickly sanity-checking a dataset before deeper modeling.
